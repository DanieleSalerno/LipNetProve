# %%
import os

from PIL import Image, ImageFilter

os.getcwd()
# Out:
# '/Users/benedettosimone/PycharmProjects/LipNetProve/DatasetITA-Ratio-B'

# %%
os.chdir('../DatasetITA-Ratio-B1')

for f in os.listdir():
    os.chdir(f)
    print(f)
    for sub in os.listdir():
        os.chdir(sub)
        print(sub)
        for img in os.listdir():
            print(img)
            image_file = Image.open(img)
            #gaussImage = image_file.filter(ImageFilter.GaussianBlur(5))
            gaussImage = image_file.filter(ImageFilter.GaussianBlur(3))
            gaussImage.save(img)
        os.chdir('..')
    os.chdir('..')
# Out:
# Test
# i
# AP_Phrases_i_05_01.png
# AP_Phrases_i_05_02.png
# AP_Phrases_i_05_03.png
# AF_Phrases_i_04.png
# RC_Phrases_i_17_02.png
# RC_Phrases_i_17_03.png
# RC_Phrases_i_17_01.png
# AF_Phrases_i_04_01.png
# RC_Phrases_i_17.png
# AP_Phrases_i_05.png
# AF_Phrases_i_04_02.png
# AF_Phrases_i_04_03.png
# g
# RC_Phrases_g_17_01.png
# RC_Phrases_g_17_03.png
# RC_Phrases_g_17_02.png
# AF_Phrases_g_04_03.png
# AF_Phrases_g_04_02.png
# AF_Phrases_g_04_01.png
# AF_Phrases_g_04.png
# AP_Phrases_g_05_03.png
# AP_Phrases_g_05_02.png
# AP_Phrases_g_05_01.png
# RC_Phrases_g_17.png
# AP_Phrases_g_05.png
# a
# RC_Word_a_17_01.png
# RC_Word_a_17_03.png
# RC_Word_a_17_02.png
# AP_Word_a_05.png
# RC_Word_a_17.png
# AP_Word_a_05_01.png
# AP_Word_a_05_03.png
# AP_Word_a_05_02.png
# buongiorno.png
# f
# RC_Phrases_f_17.png
# RC_Phrases_f_17_01.png
# AP_Phrases_f_05.png
# RC_Phrases_f_17_03.png
# RC_Phrases_f_17_02.png
# AF_Phrases_f_04_03.png
# AF_Phrases_f_04_02.png
# AF_Phrases_f_04_01.png
# ...
