# %%
import os
import matplotlib.pyplot as plt
import cv2
img=cv2.imread("provacolor2.png")
img=cv2.resize(img, (224, 224))

counter = 0
for i in range (0,7):
    for j in range (0,7):
        cropped = img[32*j:32*(j+1), 32* i:32*(i+1)]


        cv2.imwrite("frameprova%d.jpg" % counter, cropped)
        counter= counter +1
