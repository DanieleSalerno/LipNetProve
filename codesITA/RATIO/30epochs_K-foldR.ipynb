# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import KFold, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
os.getcwd()
# Out:
# 'C:\\Users\\Daniele\\PycharmProjects\\LipNetProve\\codesITA\\RATIO'

# %%
import os
os.chdir('../../DatasetITA-Ratio/Train')
os.getcwd()
# Out:
# 'C:\\Users\\Daniele\\PycharmProjects\\LipNetProve\\DatasetITA-Ratio\\Train'

# %%
data=[]
for l in os.listdir():
    if '.DS_Store' not in l:
        os.chdir(l)
        for m in os.listdir():
            data.append([l+'/'+m, l])
        os.chdir('..')

# %%
data
# Out:
# [['a/ACC_Word_a_02.png', 'a'],
#  ['a/ACC_Word_a_02_01.png', 'a'],
#  ['a/ACC_Word_a_02_02.png', 'a'],
#  ['a/ACC_Word_a_02_03.png', 'a'],
#  ['a/AC_Word_a_01.png', 'a'],
#  ['a/AC_Word_a_01_01.png', 'a'],
#  ['a/AC_Word_a_01_02.png', 'a'],
#  ['a/AC_Word_a_01_03.png', 'a'],
#  ['a/AL_Word_a_03.png', 'a'],
#  ['a/AL_Word_a_03_01.png', 'a'],
#  ['a/AL_Word_a_03_02.png', 'a'],
#  ['a/AL_Word_a_03_03.png', 'a'],
#  ['a/AR_Word_a_10.png', 'a'],
#  ['a/AR_Word_a_10_01.png', 'a'],
#  ['a/AR_Word_a_10_02.png', 'a'],
#  ['a/AR_Word_a_10_03.png', 'a'],
#  ['a/AS_Word_a_12.png', 'a'],
#  ['a/AS_Word_a_12_01.png', 'a'],
#  ['a/AS_Word_a_12_02.png', 'a'],
#  ['a/AS_Word_a_12_03.png', 'a'],
#  ['a/BC_Word_a_06.png', 'a'],
#  ['a/BC_Word_a_06_01.png', 'a'],
#  ['a/BC_Word_a_06_02.png', 'a'],
#  ['a/BC_Word_a_06_03.png', 'a'],
#  ['a/BS_Word_a_07.png', 'a'],
#  ['a/BS_Word_a_07_01.png', 'a'],
#  ['a/BS_Word_a_07_02.png', 'a'],
#  ['a/BS_Word_a_07_03.png', 'a'],
#  ['a/CF_Word_a_11.png', 'a'],
#  ['a/CF_Word_a_11_01.png', 'a'],
#  ['a/CF_Word_a_11_02.png', 'a'],
#  ['a/CF_Word_a_11_03.png', 'a'],
#  ['a/DS_Word_a_15.png', 'a'],
#  ['a/DS_Word_a_15_01.png', 'a'],
#  ['a/DS_Word_a_15_02.png', 'a'],
#  ['a/DS_Word_a_15_03.png', 'a'],
#  ['a/IB_Word_a_08.png', 'a'],
#  ['a/IB_Word_a_08_01.png', 'a'],
#  ['a/IB_Word_a_08_02.png', 'a'],
#  ['a/IB_Word_a_08_03.png', 'a'],
#  ['a/MA_Word_a_16.png', 'a'],
#  ['a/MA_Word_a_16_01.png', 'a'],
#  ['a/MA_Word_a_16_02.png', 'a'],
#  ['a/MA_Word_a_16_03.png', 'a'],
#  ['a/MC_Word_a_13.png', 'a'],
#  ['a/MC_Word_a_13_01.png', 'a'],
#  ['a/MC_Word_a_13_02.png', 'a'],
#  ['a/MC_Word_a_13_03.png', 'a'],
#  ['a/ML_Word_a_14.png', 'a'],
#  ['a/ML_Word_a_14_01.png', 'a'],
#  ['a/ML_Word_a_14_02.png', 'a'],
#  ['a/ML_Word_a_14_03.png', 'a'],
#  ['a/PC_Word_a_09.png', 'a'],
#  ['a/PC_Word_a_09_01.png', 'a'],
#  ['a/PC_Word_a_09_02.png', 'a'],
#  ['a/PC_Word_a_09_03.png', 'a'],
#  ['a/SS_Word_a_18.png', 'a'],
#  ['a/SS_Word_a_18_01.png', 'a'],
#  ['a/SS_Word_a_18_02.png', 'a'],
#  ['a/SS_Word_a_18_03.png', 'a'],
#  ['b/ACC_Word_b_02.png', 'b'],
#  ['b/ACC_Word_b_02_01.png', 'b'],
#  ['b/ACC_Word_b_02_02.png', 'b'],
#  ['b/ACC_Word_b_02_03.png', 'b'],
#  ['b/AC_Word_b_01.png', 'b'],
#  ['b/AC_Word_b_01_01.png', 'b'],
#  ['b/AC_Word_b_01_02.png', 'b'],
#  ['b/AC_Word_b_01_03.png', 'b'],
#  ['b/AL_Word_b_03.png', 'b'],
#  ['b/AL_Word_b_03_01.png', 'b'],
#  ['b/AL_Word_b_03_02.png', 'b'],
#  ['b/AL_Word_b_03_03.png', 'b'],
#  ['b/AR_Word_b_10.png', 'b'],
#  ['b/AR_Word_b_10_01.png', 'b'],
#  ['b/AR_Word_b_10_02.png', 'b'],
#  ['b/AR_Word_b_10_03.png', 'b'],
#  ['b/AS_Word_b_12.png', 'b'],
#  ['b/AS_Word_b_12_01.png', 'b'],
#  ['b/AS_Word_b_12_02.png', 'b'],
#  ['b/AS_Word_b_12_03.png', 'b'],
#  ['b/BC_Word_b_06.png', 'b'],
#  ['b/BC_Word_b_06_01.png', 'b'],
#  ['b/BC_Word_b_06_02.png', 'b'],
#  ['b/BC_Word_b_06_03.png', 'b'],
#  ['b/BS_Word_b_07.png', 'b'],
#  ['b/BS_Word_b_07_01.png', 'b'],
#  ['b/BS_Word_b_07_02.png', 'b'],
#  ['b/BS_Word_b_07_03.png', 'b'],
#  ['b/CF_Word_b_11.png', 'b'],
#  ['b/CF_Word_b_11_01.png', 'b'],
#  ['b/CF_Word_b_11_02.png', 'b'],
#  ['b/CF_Word_b_11_03.png', 'b'],
#  ['b/DS_Word_b_15.png', 'b'],
#  ['b/DS_Word_b_15_01.png', 'b'],
#  ['b/DS_Word_b_15_02.png', 'b'],
#  ['b/DS_Word_b_15_03.png', 'b'],
#  ['b/IB_Word_b_08.png', 'b'],
#  ['b/IB_Word_b_08_01.png', 'b'],
#  ['b/IB_Word_b_08_02.png', 'b'],
#  ['b/IB_Word_b_08_03.png', 'b'],
#  ['b/MA_Word_b_16.png', 'b'],
#  ['b/MA_Word_b_16_01.png', 'b'],
#  ['b/MA_Word_b_16_02.png', 'b'],
#  ['b/MA_Word_b_16_03.png', 'b'],
#  ['b/MC_Word_b_13.png', 'b'],
#  ['b/MC_Word_b_13_01.png', 'b'],
#  ['b/MC_Word_b_13_02.png', 'b'],
#  ['b/MC_Word_b_13_03.png', 'b'],
#  ['b/ML_Word_b_14.png', 'b'],
#  ['b/ML_Word_b_14_01.png', 'b'],
#  ['b/ML_Word_b_14_02.png', 'b'],
#  ['b/ML_Word_b_14_03.png', 'b'],
#  ['b/PC_Word_b_09.png', 'b'],
#  ['b/PC_Word_b_09_01.png', 'b'],
#  ['b/PC_Word_b_09_02.png', 'b'],
#  ['b/PC_Word_b_09_03.png', 'b'],
#  ['b/SS_Word_b_18.png', 'b'],
#  ['b/SS_Word_b_18_01.png', 'b'],
#  ['b/SS_Word_b_18_02.png', 'b'],
#  ['b/SS_Word_b_18_03.png', 'b'],
#  ['c/ACC_Word_c_02.png', 'c'],
#  ['c/ACC_Word_c_02_01.png', 'c'],
#  ['c/ACC_Word_c_02_02.png', 'c'],
#  ['c/ACC_Word_c_02_03.png', 'c'],
#  ['c/AC_Word_c_01.png', 'c'],
#  ['c/AC_Word_c_01_01.png', 'c'],
#  ['c/AC_Word_c_01_02.png', 'c'],
#  ['c/AC_Word_c_01_03.png', 'c'],
#  ['c/AL_Word_c_03.png', 'c'],
#  ['c/AL_Word_c_03_01.png', 'c'],
#  ['c/AL_Word_c_03_02.png', 'c'],
#  ['c/AL_Word_c_03_03.png', 'c'],
#  ['c/AR_Word_c_10.png', 'c'],
#  ['c/AR_Word_c_10_01.png', 'c'],
#  ['c/AR_Word_c_10_02.png', 'c'],
#  ['c/AR_Word_c_10_03.png', 'c'],
#  ['c/AS_Word_c_12.png', 'c'],
#  ['c/AS_Word_c_12_01.png', 'c'],
#  ['c/AS_Word_c_12_02.png', 'c'],
#  ['c/AS_Word_c_12_03.png', 'c'],
#  ['c/BC_Word_c_06.png', 'c'],
#  ['c/BC_Word_c_06_01.png', 'c'],
#  ['c/BC_Word_c_06_02.png', 'c'],
#  ['c/BC_Word_c_06_03.png', 'c'],
#  ['c/BS_Word_c_07.png', 'c'],
#  ['c/BS_Word_c_07_01.png', 'c'],
#  ['c/BS_Word_c_07_02.png', 'c'],
#  ['c/BS_Word_c_07_03.png', 'c'],
#  ['c/CF_Word_c_11.png', 'c'],
#  ['c/CF_Word_c_11_01.png', 'c'],
#  ['c/CF_Word_c_11_02.png', 'c'],
#  ['c/CF_Word_c_11_03.png', 'c'],
#  ['c/DS_Word_c_15.png', 'c'],
#  ['c/DS_Word_c_15_01.png', 'c'],
#  ['c/DS_Word_c_15_02.png', 'c'],
#  ['c/DS_Word_c_15_03.png', 'c'],
#  ['c/IB_Word_c_08.png', 'c'],
#  ['c/IB_Word_c_08_01.png', 'c'],
#  ['c/IB_Word_c_08_02.png', 'c'],
#  ['c/IB_Word_c_08_03.png', 'c'],
#  ['c/MA_Word_c_16.png', 'c'],
#  ['c/MA_Word_c_16_01.png', 'c'],
#  ['c/MA_Word_c_16_02.png', 'c'],
#  ['c/MA_Word_c_16_03.png', 'c'],
#  ['c/MC_Word_c_13.png', 'c'],
#  ['c/MC_Word_c_13_01.png', 'c'],
#  ['c/MC_Word_c_13_02.png', 'c'],
#  ['c/MC_Word_c_13_03.png', 'c'],
#  ['c/ML_Word_c_14.png', 'c'],
#  ['c/ML_Word_c_14_01.png', 'c'],
#  ['c/ML_Word_c_14_02.png', 'c'],
#  ['c/ML_Word_c_14_03.png', 'c'],
#  ['c/PC_Word_c_09.png', 'c'],
#  ['c/PC_Word_c_09_01.png', 'c'],
#  ['c/PC_Word_c_09_02.png', 'c'],
#  ['c/PC_Word_c_09_03.png', 'c'],
#  ['c/SS_Word_c_18.png', 'c'],
#  ['c/SS_Word_c_18_01.png', 'c'],
#  ['c/SS_Word_c_18_02.png', 'c'],
#  ['c/SS_Word_c_18_03.png', 'c'],
#  ['d/ACC_Word_d_02.png', 'd'],
#  ['d/ACC_Word_d_02_01.png', 'd'],
#  ['d/ACC_Word_d_02_02.png', 'd'],
#  ['d/ACC_Word_d_02_03.png', 'd'],
#  ['d/AC_Word_d_01.png', 'd'],
#  ['d/AC_Word_d_01_01.png', 'd'],
#  ['d/AC_Word_d_01_02.png', 'd'],
#  ['d/AC_Word_d_01_03.png', 'd'],
#  ['d/AL_Word_d_03.png', 'd'],
#  ['d/AL_Word_d_03_01.png', 'd'],
#  ['d/AL_Word_d_03_02.png', 'd'],
#  ['d/AL_Word_d_03_03.png', 'd'],
#  ['d/AR_Word_d_10.png', 'd'],
#  ['d/AR_Word_d_10_01.png', 'd'],
#  ['d/AR_Word_d_10_02.png', 'd'],
#  ['d/AR_Word_d_10_03.png', 'd'],
#  ['d/AS_Word_d_12.png', 'd'],
#  ['d/AS_Word_d_12_01.png', 'd'],
#  ['d/AS_Word_d_12_02.png', 'd'],
#  ['d/AS_Word_d_12_03.png', 'd'],
#  ['d/BC_Word_d_06.png', 'd'],
#  ['d/BC_Word_d_06_01.png', 'd'],
#  ['d/BC_Word_d_06_02.png', 'd'],
#  ['d/BC_Word_d_06_03.png', 'd'],
#  ['d/BS_Word_d_07.png', 'd'],
#  ['d/BS_Word_d_07_01.png', 'd'],
#  ['d/BS_Word_d_07_02.png', 'd'],
#  ['d/BS_Word_d_07_03.png', 'd'],
#  ['d/CF_Word_d_11.png', 'd'],
#  ['d/CF_Word_d_11_01.png', 'd'],
#  ['d/CF_Word_d_11_02.png', 'd'],
#  ['d/CF_Word_d_11_03.png', 'd'],
#  ['d/DS_Word_d_15.png', 'd'],
#  ['d/DS_Word_d_15_01.png', 'd'],
#  ['d/DS_Word_d_15_02.png', 'd'],
#  ['d/DS_Word_d_15_03.png', 'd'],
#  ['d/IB_Word_d_08.png', 'd'],
#  ['d/IB_Word_d_08_01.png', 'd'],
#  ['d/IB_Word_d_08_02.png', 'd'],
#  ['d/IB_Word_d_08_03.png', 'd'],
#  ['d/MA_Word_d_16.png', 'd'],
#  ['d/MA_Word_d_16_01.png', 'd'],
#  ['d/MA_Word_d_16_02.png', 'd'],
#  ['d/MA_Word_d_16_03.png', 'd'],
#  ['d/MC_Word_d_13.png', 'd'],
#  ['d/MC_Word_d_13_01.png', 'd'],
#  ['d/MC_Word_d_13_02.png', 'd'],
#  ['d/MC_Word_d_13_03.png', 'd'],
#  ['d/ML_Word_d_14.png', 'd'],
#  ['d/ML_Word_d_14_01.png', 'd'],
#  ['d/ML_Word_d_14_02.png', 'd'],
#  ['d/ML_Word_d_14_03.png', 'd'],
#  ['d/PC_Word_d_09.png', 'd'],
#  ['d/PC_Word_d_09_01.png', 'd'],
#  ['d/PC_Word_d_09_02.png', 'd'],
#  ['d/PC_Word_d_09_03.png', 'd'],
#  ['d/SS_Word_d_18.png', 'd'],
#  ['d/SS_Word_d_18_01.png', 'd'],
#  ['d/SS_Word_d_18_02.png', 'd'],
#  ['d/SS_Word_d_18_03.png', 'd'],
#  ['e/ACC_Word_e_02.png', 'e'],
#  ['e/ACC_Word_e_02_01.png', 'e'],
#  ['e/ACC_Word_e_02_02.png', 'e'],
#  ['e/ACC_Word_e_02_03.png', 'e'],
#  ['e/AC_Word_e_01.png', 'e'],
#  ['e/AC_Word_e_01_01.png', 'e'],
#  ['e/AC_Word_e_01_02.png', 'e'],
#  ['e/AC_Word_e_01_03.png', 'e'],
#  ['e/AF_Word_e_04.png', 'e'],
#  ['e/AL_Word_e_03.png', 'e'],
#  ['e/AL_Word_e_03_01.png', 'e'],
#  ['e/AL_Word_e_03_02.png', 'e'],
#  ['e/AL_Word_e_03_03.png', 'e'],
#  ['e/AR_Word_e_10.png', 'e'],
#  ['e/AR_Word_e_10_01.png', 'e'],
#  ['e/AR_Word_e_10_02.png', 'e'],
#  ['e/AR_Word_e_10_03.png', 'e'],
#  ['e/AS_Word_e_12.png', 'e'],
#  ['e/AS_Word_e_12_01.png', 'e'],
#  ['e/AS_Word_e_12_02.png', 'e'],
#  ['e/AS_Word_e_12_03.png', 'e'],
#  ['e/BC_Word_e_06.png', 'e'],
#  ['e/BC_Word_e_06_01.png', 'e'],
#  ['e/BC_Word_e_06_02.png', 'e'],
#  ['e/BC_Word_e_06_03.png', 'e'],
#  ['e/BS_Word_e_07.png', 'e'],
#  ['e/BS_Word_e_07_01.png', 'e'],
#  ['e/BS_Word_e_07_02.png', 'e'],
#  ['e/BS_Word_e_07_03.png', 'e'],
#  ['e/CF_Word_e_11.png', 'e'],
#  ['e/CF_Word_e_11_01.png', 'e'],
#  ['e/CF_Word_e_11_02.png', 'e'],
#  ['e/CF_Word_e_11_03.png', 'e'],
#  ['e/DS_Word_e_15.png', 'e'],
#  ['e/DS_Word_e_15_01.png', 'e'],
#  ['e/DS_Word_e_15_02.png', 'e'],
#  ['e/DS_Word_e_15_03.png', 'e'],
#  ['e/IB_Word_e_08.png', 'e'],
#  ['e/IB_Word_e_08_01.png', 'e'],
#  ['e/IB_Word_e_08_02.png', 'e'],
#  ['e/IB_Word_e_08_03.png', 'e'],
#  ['e/MA_Word_e_16.png', 'e'],
#  ['e/MA_Word_e_16_01.png', 'e'],
#  ['e/MA_Word_e_16_02.png', 'e'],
#  ['e/MA_Word_e_16_03.png', 'e'],
#  ['e/MC_Word_e_13.png', 'e'],
#  ['e/MC_Word_e_13_01.png', 'e'],
#  ['e/MC_Word_e_13_02.png', 'e'],
#  ['e/MC_Word_e_13_03.png', 'e'],
#  ['e/ML_Word_e_14.png', 'e'],
#  ['e/ML_Word_e_14_01.png', 'e'],
#  ['e/ML_Word_e_14_02.png', 'e'],
#  ['e/ML_Word_e_14_03.png', 'e'],
#  ['e/PC_Word_e_09.png', 'e'],
#  ['e/PC_Word_e_09_01.png', 'e'],
#  ['e/PC_Word_e_09_02.png', 'e'],
#  ['e/PC_Word_e_09_03.png', 'e'],
#  ['e/SS_Word_e_18.png', 'e'],
#  ['e/SS_Word_e_18_01.png', 'e'],
#  ['e/SS_Word_e_18_02.png', 'e'],
#  ['e/SS_Word_e_18_03.png', 'e'],
#  ['f/ACC_Phrases_f_02.png', 'f'],
#  ['f/ACC_Phrases_f_02_01.png', 'f'],
#  ['f/ACC_Phrases_f_02_02.png', 'f'],
#  ['f/ACC_Phrases_f_02_03.png', 'f'],
#  ['f/AC_Phrases_f_01.png', 'f'],
#  ['f/AC_Phrases_f_01_01.png', 'f'],
#  ['f/AC_Phrases_f_01_02.png', 'f'],
#  ['f/AC_Phrases_f_01_03.png', 'f'],
#  ['f/AF_Phrases_f_04.png', 'f'],
#  ['f/AL_Phrases_f_03.png', 'f'],
#  ['f/AL_Phrases_f_03_01.png', 'f'],
#  ['f/AL_Phrases_f_03_02.png', 'f'],
#  ['f/AL_Phrases_f_03_03.png', 'f'],
#  ['f/AR_Phrases_f_10.png', 'f'],
#  ['f/AR_Phrases_f_10_01.png', 'f'],
#  ['f/AR_Phrases_f_10_02.png', 'f'],
#  ['f/AR_Phrases_f_10_03.png', 'f'],
#  ['f/AS_Phrases_f_12.png', 'f'],
#  ['f/AS_Phrases_f_12_01.png', 'f'],
#  ['f/AS_Phrases_f_12_02.png', 'f'],
#  ['f/AS_Phrases_f_12_03.png', 'f'],
#  ['f/BC_Phrases_f_06.png', 'f'],
#  ['f/BC_Phrases_f_06_01.png', 'f'],
#  ['f/BC_Phrases_f_06_02.png', 'f'],
#  ['f/BC_Phrases_f_06_03.png', 'f'],
#  ['f/BS_Phrases_f_07.png', 'f'],
#  ['f/BS_Phrases_f_07_01.png', 'f'],
#  ['f/BS_Phrases_f_07_02.png', 'f'],
#  ['f/BS_Phrases_f_07_03.png', 'f'],
#  ['f/CF_Phrases_f_11.png', 'f'],
#  ['f/CF_Phrases_f_11_01.png', 'f'],
#  ['f/CF_Phrases_f_11_02.png', 'f'],
#  ['f/CF_Phrases_f_11_03.png', 'f'],
#  ['f/DS_Phrases_f_15.png', 'f'],
#  ['f/DS_Phrases_f_15_01.png', 'f'],
#  ['f/DS_Phrases_f_15_02.png', 'f'],
#  ['f/DS_Phrases_f_15_03.png', 'f'],
#  ['f/IB_Phrases_f_08.png', 'f'],
#  ['f/IB_Phrases_f_08_01.png', 'f'],
#  ['f/IB_Phrases_f_08_02.png', 'f'],
#  ['f/IB_Phrases_f_08_03.png', 'f'],
#  ['f/MA_Phrases_f_16.png', 'f'],
#  ['f/MA_Phrases_f_16_01.png', 'f'],
#  ['f/MA_Phrases_f_16_02.png', 'f'],
#  ['f/MA_Phrases_f_16_03.png', 'f'],
#  ['f/MC_Phrases_f_13.png', 'f'],
#  ['f/MC_Phrases_f_13_01.png', 'f'],
#  ['f/MC_Phrases_f_13_02.png', 'f'],
#  ['f/MC_Phrases_f_13_03.png', 'f'],
#  ['f/ML_Phrases_f_14.png', 'f'],
#  ['f/ML_Phrases_f_14_01.png', 'f'],
#  ['f/ML_Phrases_f_14_02.png', 'f'],
#  ['f/ML_Phrases_f_14_03.png', 'f'],
#  ['f/PC_Phrases_f_09.png', 'f'],
#  ['f/PC_Phrases_f_09_01.png', 'f'],
#  ['f/PC_Phrases_f_09_02.png', 'f'],
#  ['f/PC_Phrases_f_09_03.png', 'f'],
#  ['f/SS_Phrases_f_18.png', 'f'],
#  ['f/SS_Phrases_f_18_01.png', 'f'],
#  ['f/SS_Phrases_f_18_02.png', 'f'],
#  ['f/SS_Phrases_f_18_03.png', 'f'],
#  ['g/ACC_Phrases_g_02.png', 'g'],
#  ['g/ACC_Phrases_g_02_01.png', 'g'],
#  ['g/ACC_Phrases_g_02_02.png', 'g'],
#  ['g/ACC_Phrases_g_02_03.png', 'g'],
#  ['g/AC_Phrases_g_01.png', 'g'],
#  ['g/AC_Phrases_g_01_01.png', 'g'],
#  ['g/AC_Phrases_g_01_02.png', 'g'],
#  ['g/AC_Phrases_g_01_03.png', 'g'],
#  ['g/AF_Phrases_g_04.png', 'g'],
#  ['g/AL_Phrases_g_03.png', 'g'],
#  ['g/AL_Phrases_g_03_01.png', 'g'],
#  ['g/AL_Phrases_g_03_02.png', 'g'],
#  ['g/AL_Phrases_g_03_03.png', 'g'],
#  ['g/AR_Phrases_g_10.png', 'g'],
#  ['g/AR_Phrases_g_10_01.png', 'g'],
#  ['g/AR_Phrases_g_10_02.png', 'g'],
#  ['g/AR_Phrases_g_10_03.png', 'g'],
#  ['g/AS_Phrases_g_12.png', 'g'],
#  ['g/AS_Phrases_g_12_01.png', 'g'],
#  ['g/AS_Phrases_g_12_02.png', 'g'],
#  ['g/AS_Phrases_g_12_03.png', 'g'],
#  ['g/BC_Phrases_g_06.png', 'g'],
#  ['g/BC_Phrases_g_06_01.png', 'g'],
#  ['g/BC_Phrases_g_06_02.png', 'g'],
#  ['g/BC_Phrases_g_06_03.png', 'g'],
#  ['g/BS_Phrases_g_07.png', 'g'],
#  ['g/BS_Phrases_g_07_01.png', 'g'],
#  ['g/BS_Phrases_g_07_02.png', 'g'],
#  ['g/BS_Phrases_g_07_03.png', 'g'],
#  ['g/CF_Phrases_g_11.png', 'g'],
#  ['g/CF_Phrases_g_11_01.png', 'g'],
#  ['g/CF_Phrases_g_11_02.png', 'g'],
#  ['g/CF_Phrases_g_11_03.png', 'g'],
#  ['g/DS_Phrases_g_15.png', 'g'],
#  ['g/DS_Phrases_g_15_01.png', 'g'],
#  ['g/DS_Phrases_g_15_02.png', 'g'],
#  ['g/DS_Phrases_g_15_03.png', 'g'],
#  ['g/MA_Phrases_g_16.png', 'g'],
#  ['g/MA_Phrases_g_16_01.png', 'g'],
#  ['g/MA_Phrases_g_16_02.png', 'g'],
#  ['g/MA_Phrases_g_16_03.png', 'g'],
#  ['g/MC_Phrases_g_13.png', 'g'],
#  ['g/MC_Phrases_g_13_01.png', 'g'],
#  ['g/MC_Phrases_g_13_02.png', 'g'],
#  ['g/MC_Phrases_g_13_03.png', 'g'],
#  ['g/ML_Phrases_g_14.png', 'g'],
#  ['g/ML_Phrases_g_14_01.png', 'g'],
#  ['g/ML_Phrases_g_14_02.png', 'g'],
#  ['g/ML_Phrases_g_14_03.png', 'g'],
#  ['g/PC_Phrases_g_09.png', 'g'],
#  ['g/PC_Phrases_g_09_01.png', 'g'],
#  ['g/PC_Phrases_g_09_02.png', 'g'],
#  ['g/PC_Phrases_g_09_03.png', 'g'],
#  ['g/SS_Phrases_g_18.png', 'g'],
#  ['g/SS_Phrases_g_18_01.png', 'g'],
#  ['g/SS_Phrases_g_18_02.png', 'g'],
#  ['g/SS_Phrases_g_18_03.png', 'g'],
#  ['h/ACC_Phrases_h_02.png', 'h'],
#  ['h/ACC_Phrases_h_02_01.png', 'h'],
#  ['h/ACC_Phrases_h_02_02.png', 'h'],
#  ['h/ACC_Phrases_h_02_03.png', 'h'],
#  ['h/AC_Phrases_h_01.png', 'h'],
#  ['h/AC_Phrases_h_01_01.png', 'h'],
#  ['h/AC_Phrases_h_01_02.png', 'h'],
#  ['h/AC_Phrases_h_01_03.png', 'h'],
#  ['h/AF_Phrases_h_04.png', 'h'],
#  ['h/AL_Phrases_h_03.png', 'h'],
#  ['h/AL_Phrases_h_03_01.png', 'h'],
#  ['h/AL_Phrases_h_03_02.png', 'h'],
#  ['h/AL_Phrases_h_03_03.png', 'h'],
#  ['h/AR_Phrases_h_10.png', 'h'],
#  ['h/AR_Phrases_h_10_01.png', 'h'],
#  ['h/AR_Phrases_h_10_02.png', 'h'],
#  ['h/AR_Phrases_h_10_03.png', 'h'],
#  ['h/AS_Phrases_h_12.png', 'h'],
#  ['h/AS_Phrases_h_12_01.png', 'h'],
#  ['h/AS_Phrases_h_12_02.png', 'h'],
#  ['h/AS_Phrases_h_12_03.png', 'h'],
#  ['h/BC_Phrases_h_06.png', 'h'],
#  ['h/BC_Phrases_h_06_01.png', 'h'],
#  ['h/BC_Phrases_h_06_02.png', 'h'],
#  ['h/BC_Phrases_h_06_03.png', 'h'],
#  ['h/BS_Phrases_h_07.png', 'h'],
#  ['h/BS_Phrases_h_07_01.png', 'h'],
#  ['h/BS_Phrases_h_07_02.png', 'h'],
#  ['h/BS_Phrases_h_07_03.png', 'h'],
#  ['h/CF_Phrases_h_11.png', 'h'],
#  ['h/CF_Phrases_h_11_01.png', 'h'],
#  ['h/CF_Phrases_h_11_02.png', 'h'],
#  ['h/CF_Phrases_h_11_03.png', 'h'],
#  ['h/DS_Phrases_h_15.png', 'h'],
#  ['h/DS_Phrases_h_15_01.png', 'h'],
#  ['h/DS_Phrases_h_15_02.png', 'h'],
#  ['h/DS_Phrases_h_15_03.png', 'h'],
#  ['h/MA_Phrases_h_16.png', 'h'],
#  ['h/MA_Phrases_h_16_01.png', 'h'],
#  ['h/MA_Phrases_h_16_02.png', 'h'],
#  ['h/MA_Phrases_h_16_03.png', 'h'],
#  ['h/MC_Phrases_h_13.png', 'h'],
#  ['h/MC_Phrases_h_13_01.png', 'h'],
#  ['h/MC_Phrases_h_13_02.png', 'h'],
#  ['h/MC_Phrases_h_13_03.png', 'h'],
#  ['h/ML_Phrases_h_14.png', 'h'],
#  ['h/ML_Phrases_h_14_01.png', 'h'],
#  ['h/ML_Phrases_h_14_02.png', 'h'],
#  ['h/ML_Phrases_h_14_03.png', 'h'],
#  ['h/PC_Phrases_h_09.png', 'h'],
#  ['h/PC_Phrases_h_09_01.png', 'h'],
#  ['h/PC_Phrases_h_09_02.png', 'h'],
#  ['h/PC_Phrases_h_09_03.png', 'h'],
#  ['h/SS_Phrases_h_18.png', 'h'],
#  ['h/SS_Phrases_h_18_01.png', 'h'],
#  ['h/SS_Phrases_h_18_02.png', 'h'],
#  ['h/SS_Phrases_h_18_03.png', 'h'],
#  ['i/ACC_Phrases_i_02.png', 'i'],
#  ['i/ACC_Phrases_i_02_01.png', 'i'],
#  ['i/ACC_Phrases_i_02_02.png', 'i'],
#  ['i/ACC_Phrases_i_02_03.png', 'i'],
#  ['i/AC_Phrases_i_01.png', 'i'],
#  ['i/AC_Phrases_i_01_01.png', 'i'],
#  ['i/AC_Phrases_i_01_02.png', 'i'],
#  ['i/AC_Phrases_i_01_03.png', 'i'],
#  ['i/AF_Phrases_i_04.png', 'i'],
#  ['i/AL_Phrases_i_03.png', 'i'],
#  ['i/AL_Phrases_i_03_01.png', 'i'],
#  ['i/AL_Phrases_i_03_02.png', 'i'],
#  ['i/AL_Phrases_i_03_03.png', 'i'],
#  ['i/AR_Phrases_i_10.png', 'i'],
#  ['i/AR_Phrases_i_10_01.png', 'i'],
#  ['i/AR_Phrases_i_10_02.png', 'i'],
#  ['i/AR_Phrases_i_10_03.png', 'i'],
#  ['i/AS_Phrases_i_12.png', 'i'],
#  ['i/AS_Phrases_i_12_01.png', 'i'],
#  ['i/AS_Phrases_i_12_02.png', 'i'],
#  ['i/AS_Phrases_i_12_03.png', 'i'],
#  ['i/BC_Phrases_i_06.png', 'i'],
#  ['i/BC_Phrases_i_06_01.png', 'i'],
#  ['i/BC_Phrases_i_06_02.png', 'i'],
#  ['i/BC_Phrases_i_06_03.png', 'i'],
#  ['i/BS_Phrases_i_07.png', 'i'],
#  ['i/BS_Phrases_i_07_01.png', 'i'],
#  ['i/BS_Phrases_i_07_02.png', 'i'],
#  ['i/BS_Phrases_i_07_03.png', 'i'],
#  ['i/CF_Phrases_i_11.png', 'i'],
#  ['i/CF_Phrases_i_11_01.png', 'i'],
#  ['i/CF_Phrases_i_11_02.png', 'i'],
#  ['i/CF_Phrases_i_11_03.png', 'i'],
#  ['i/DS_Phrases_i_15.png', 'i'],
#  ['i/DS_Phrases_i_15_01.png', 'i'],
#  ['i/DS_Phrases_i_15_02.png', 'i'],
#  ['i/DS_Phrases_i_15_03.png', 'i'],
#  ['i/IB_Phrases_i_08.png', 'i'],
#  ['i/IB_Phrases_i_08_01.png', 'i'],
#  ['i/IB_Phrases_i_08_02.png', 'i'],
#  ['i/IB_Phrases_i_08_03.png', 'i'],
#  ['i/MA_Phrases_i_16.png', 'i'],
#  ['i/MA_Phrases_i_16_01.png', 'i'],
#  ['i/MA_Phrases_i_16_02.png', 'i'],
#  ['i/MA_Phrases_i_16_03.png', 'i'],
#  ['i/MC_Phrases_i_13.png', 'i'],
#  ['i/MC_Phrases_i_13_01.png', 'i'],
#  ['i/MC_Phrases_i_13_02.png', 'i'],
#  ['i/MC_Phrases_i_13_03.png', 'i'],
#  ['i/ML_Phrases_i_14.png', 'i'],
#  ['i/ML_Phrases_i_14_01.png', 'i'],
#  ['i/ML_Phrases_i_14_02.png', 'i'],
#  ['i/ML_Phrases_i_14_03.png', 'i'],
#  ['i/PC_Phrases_i_09.png', 'i'],
#  ['i/PC_Phrases_i_09_01.png', 'i'],
#  ['i/PC_Phrases_i_09_02.png', 'i'],
#  ['i/PC_Phrases_i_09_03.png', 'i'],
#  ['i/SS_Phrases_i_18.png', 'i'],
#  ['i/SS_Phrases_i_18_01.png', 'i'],
#  ['i/SS_Phrases_i_18_02.png', 'i'],
#  ['i/SS_Phrases_i_18_03.png', 'i'],
#  ['j/ACC_Phrases_j_02.png', 'j'],
#  ['j/ACC_Phrases_j_02_01.png', 'j'],
#  ['j/ACC_Phrases_j_02_02.png', 'j'],
#  ['j/ACC_Phrases_j_02_03.png', 'j'],
#  ['j/AC_Phrases_j_01.png', 'j'],
#  ['j/AC_Phrases_j_01_01.png', 'j'],
#  ['j/AC_Phrases_j_01_02.png', 'j'],
#  ['j/AC_Phrases_j_01_03.png', 'j'],
#  ['j/AF_Phrases_j_04.png', 'j'],
#  ['j/AL_Phrases_j_03.png', 'j'],
#  ['j/AL_Phrases_j_03_01.png', 'j'],
#  ['j/AL_Phrases_j_03_02.png', 'j'],
#  ['j/AL_Phrases_j_03_03.png', 'j'],
#  ['j/AR_Phrases_j_10.png', 'j'],
#  ['j/AR_Phrases_j_10_01.png', 'j'],
#  ['j/AR_Phrases_j_10_02.png', 'j'],
#  ['j/AR_Phrases_j_10_03.png', 'j'],
#  ['j/AS_Phrases_j_12.png', 'j'],
#  ['j/AS_Phrases_j_12_01.png', 'j'],
#  ['j/AS_Phrases_j_12_02.png', 'j'],
#  ['j/AS_Phrases_j_12_03.png', 'j'],
#  ['j/BC_Phrases_j_06.png', 'j'],
#  ['j/BC_Phrases_j_06_01.png', 'j'],
#  ['j/BC_Phrases_j_06_02.png', 'j'],
#  ['j/BC_Phrases_j_06_03.png', 'j'],
#  ['j/BS_Phrases_j_07.png', 'j'],
#  ['j/BS_Phrases_j_07_01.png', 'j'],
#  ['j/BS_Phrases_j_07_02.png', 'j'],
#  ['j/BS_Phrases_j_07_03.png', 'j'],
#  ['j/CF_Phrases_j_11.png', 'j'],
#  ['j/CF_Phrases_j_11_01.png', 'j'],
#  ['j/CF_Phrases_j_11_02.png', 'j'],
#  ['j/CF_Phrases_j_11_03.png', 'j'],
#  ['j/DS_Phrases_j_15.png', 'j'],
#  ['j/DS_Phrases_j_15_01.png', 'j'],
#  ['j/DS_Phrases_j_15_02.png', 'j'],
#  ['j/DS_Phrases_j_15_03.png', 'j'],
#  ['j/MA_Phrases_j_16.png', 'j'],
#  ['j/MA_Phrases_j_16_01.png', 'j'],
#  ['j/MA_Phrases_j_16_02.png', 'j'],
#  ['j/MA_Phrases_j_16_03.png', 'j'],
#  ['j/MC_Phrases_j_13.png', 'j'],
#  ['j/MC_Phrases_j_13_01.png', 'j'],
#  ['j/MC_Phrases_j_13_02.png', 'j'],
#  ['j/MC_Phrases_j_13_03.png', 'j'],
#  ['j/ML_Phrases_j_14.png', 'j'],
#  ['j/ML_Phrases_j_14_01.png', 'j'],
#  ['j/ML_Phrases_j_14_02.png', 'j'],
#  ['j/ML_Phrases_j_14_03.png', 'j'],
#  ['j/PC_Phrases_j_09.png', 'j'],
#  ['j/PC_Phrases_j_09_01.png', 'j'],
#  ['j/PC_Phrases_j_09_02.png', 'j'],
#  ['j/PC_Phrases_j_09_03.png', 'j'],
#  ['j/SS_Phrases_j_18.png', 'j'],
#  ['j/SS_Phrases_j_18_01.png', 'j'],
#  ['j/SS_Phrases_j_18_02.png', 'j'],
#  ['j/SS_Phrases_j_18_03.png', 'j']]

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Daniele\\PycharmProjects\\LipNetProve\\DatasetITA-Ratio\\Train'

# %%
len(data)
# Out:
# 594

# %%
import csv
os.chdir('../../codesITA')
header = ['filename', 'label']

with open('training_labelsITA.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write multiple rows
    writer.writerows(data)

# %%
train_data = pd.read_csv('training_labelsITA.csv')
Y = train_data[['label']]

kf = KFold(n_splits = 5)

skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True)

# %%
idg = ImageDataGenerator(rescale=1./255)

# %%
def get_model_name(k):
    return 'model_'+str(k)+'.h5'

# %%
def create_new_model():
    import os
    import numpy as np
    from keras.models import Sequential # To initialise the nn as a sequence of layers
    from keras.layers import Convolution2D # To make the convolution layer for 2D images
    from keras.layers import MaxPooling2D #
    from keras.layers import Flatten
    from keras.layers import Dense
    from keras.layers import Dropout
    from keras.callbacks import CSVLogger
    from tensorflow.keras.optimizers import RMSprop
    from keras.layers import BatchNormalization
    from tensorflow.keras.optimizers import Adam
    from keras.models import load_model
    from keras.callbacks import ModelCheckpoint
    from keras.layers import Activation
    from keras.layers import GlobalAveragePooling2D

    
    csv = CSVLogger("2_adam_30epochRatio.log")
    #filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
    #checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    # Initialising the CNN
    classifier = Sequential()

    # Step 1 - Convolution
    classifier.add(Convolution2D(32, (2, 2), input_shape=(224, 224, 1), activation='relu', strides=2, name='convo1'))
    #classifier.add(Convolution2D(64, (3, 3), activation='relu', name='convo2'))
    # Step 1 - Pooling
    classifier.add(MaxPooling2D(pool_size=(2, 2)))

    # Step 2 - Convolution
    classifier.add(Convolution2D(64, (3, 3), activation='relu', name='convo3'))
    # Step 2 - Pooling
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    # Step 3 - Convolution
    #classifier.add(Convolution2D(64, (3, 3), activation='relu', name='convo4'))
    # Step 3 - Pooling
    #classifier.add(MaxPooling2D(pool_size=(2, 2)))
    #Step 4 - Flattening

    classifier.add(Flatten())

    classifier.add(BatchNormalization())
    #classifier.add(Dropout((0.5)))
    classifier.add(Dense(512, activation='relu'))

    '''classifier.add(BatchNormalization())
    classifier.add(Dropout((0.5)))
    classifier.add(Dense(512, activation = 'relu'))
    '''

    classifier.add(BatchNormalization())
    #classifier.add(Dropout((0.4)))
    classifier.add(Dense(10, activation='softmax'))

    return classifier

# %%
VALIDATION_ACCURACY = []
VALIDATION_LOSS = []

save_dir = 'saved_models(30epoch)ITARATIO/'
fold_var = 1

for train_index, val_index in skf.split(np.zeros(len(data)),Y):
    training_data = train_data.iloc[train_index]
    validation_data = train_data.iloc[val_index]

    train_data_generator = idg.flow_from_dataframe(training_data, directory = '../DatasetITA-Ratio/Train',
                               x_col = "filename", y_col = "label",
                               class_mode = "categorical", shuffle = True, color_mode="grayscale",target_size=(224,224),batchsize=32)
    valid_data_generator  = idg.flow_from_dataframe(validation_data, directory =  '../DatasetITA-Ratio/Train',
                            x_col = "filename", y_col = "label",
                            class_mode = "categorical", shuffle = True, color_mode="grayscale",target_size=(224,224),batchsize=32)

    # CREATE NEW MODEL
    model = create_new_model()
    # COMPILE NEW MODEL
    model.compile(loss='categorical_crossentropy',
              optimizer="Adam",
              metrics=['accuracy'])

    # CREATE CALLBACKS
    checkpoint = tf.keras.callbacks.ModelCheckpoint(save_dir+get_model_name(fold_var),
                            monitor='val_accuracy', verbose=1,
                            save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    # There can be other callbacks, but just showing one because it involves the model name
    # This saves the best model
    # FIT THE MODEL
    h = model.fit(train_data_generator,
                epochs=30,
                callbacks=callbacks_list,
                validation_data=valid_data_generator)
    #PLOT HISTORY
    #:
    #:

    # LOAD BEST MODEL to evaluate the performance of the model
    model.load_weights("saved_models(30epoch)ITARATIO/model_"+str(fold_var)+".h5")
    

    results = model.evaluate(valid_data_generator)
    results = dict(zip(model.metrics_names,results))

    VALIDATION_ACCURACY.append(results['accuracy'])
    VALIDATION_LOSS.append(results['loss'])

    plt.plot(h.history['accuracy']) #validation
    plt.plot(h.history['val_accuracy']) #train
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    tf.keras.backend.clear_session()

    fold_var += 1
# Out:
# Found 475 validated image filenames belonging to 10 classes.
# Found 119 validated image filenames belonging to 10 classes.
# Epoch 1/30
# 15/15 [==============================] - ETA: 0s - loss: 3.0707 - accuracy: 0.1263
# Epoch 00001: val_accuracy improved from -inf to 0.11765, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 6s 338ms/step - loss: 3.0707 - accuracy: 0.1263 - val_loss: 2.4265 - val_accuracy: 0.1176
# Epoch 2/30
# 15/15 [==============================] - ETA: 0s - loss: 2.2094 - accuracy: 0.2042
# Epoch 00002: val_accuracy improved from 0.11765 to 0.15126, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 320ms/step - loss: 2.2094 - accuracy: 0.2042 - val_loss: 2.2868 - val_accuracy: 0.1513
# Epoch 3/30
# 15/15 [==============================] - ETA: 0s - loss: 1.8046 - accuracy: 0.4021
# Epoch 00003: val_accuracy did not improve from 0.15126
# 15/15 [==============================] - 5s 299ms/step - loss: 1.8046 - accuracy: 0.4021 - val_loss: 2.2769 - val_accuracy: 0.1092
# Epoch 4/30
# 15/15 [==============================] - ETA: 0s - loss: 1.2049 - accuracy: 0.6295
# Epoch 00004: val_accuracy improved from 0.15126 to 0.31092, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 312ms/step - loss: 1.2049 - accuracy: 0.6295 - val_loss: 2.2464 - val_accuracy: 0.3109
# Epoch 5/30
# 15/15 [==============================] - ETA: 0s - loss: 0.4918 - accuracy: 0.8589
# Epoch 00005: val_accuracy did not improve from 0.31092
# 15/15 [==============================] - 4s 289ms/step - loss: 0.4918 - accuracy: 0.8589 - val_loss: 2.2359 - val_accuracy: 0.2017
# Epoch 6/30
# 15/15 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.9242
# Epoch 00006: val_accuracy did not improve from 0.31092
# 15/15 [==============================] - 4s 291ms/step - loss: 0.2591 - accuracy: 0.9242 - val_loss: 2.2387 - val_accuracy: 0.1765
# Epoch 7/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9474
# Epoch 00007: val_accuracy did not improve from 0.31092
# 15/15 [==============================] - 4s 285ms/step - loss: 0.1680 - accuracy: 0.9474 - val_loss: 2.2143 - val_accuracy: 0.2437
# Epoch 8/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0880 - accuracy: 0.9768
# Epoch 00008: val_accuracy did not improve from 0.31092
# 15/15 [==============================] - 4s 290ms/step - loss: 0.0880 - accuracy: 0.9768 - val_loss: 2.2159 - val_accuracy: 0.2857
# Epoch 9/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9979
# Epoch 00009: val_accuracy improved from 0.31092 to 0.32773, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0320 - accuracy: 0.9979 - val_loss: 2.1823 - val_accuracy: 0.3277
# Epoch 10/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9979
# Epoch 00010: val_accuracy improved from 0.32773 to 0.35294, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0176 - accuracy: 0.9979 - val_loss: 2.1599 - val_accuracy: 0.3529
# Epoch 11/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9979
# Epoch 00011: val_accuracy improved from 0.35294 to 0.36134, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 2.1348 - val_accuracy: 0.3613
# Epoch 12/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 00012: val_accuracy improved from 0.36134 to 0.43697, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.1001 - val_accuracy: 0.4370
# Epoch 13/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00013: val_accuracy did not improve from 0.43697
# 15/15 [==============================] - 4s 284ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 2.0750 - val_accuracy: 0.4202
# Epoch 14/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9979
# Epoch 00014: val_accuracy did not improve from 0.43697
# 15/15 [==============================] - 4s 280ms/step - loss: 0.0085 - accuracy: 0.9979 - val_loss: 2.0594 - val_accuracy: 0.4118
# Epoch 15/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 1.0000
# Epoch 00015: val_accuracy improved from 0.43697 to 0.55462, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 303ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.0149 - val_accuracy: 0.5546
# Epoch 16/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00016: val_accuracy improved from 0.55462 to 0.60504, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 323ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.9631 - val_accuracy: 0.6050
# Epoch 17/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00017: val_accuracy improved from 0.60504 to 0.66387, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 315ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.9062 - val_accuracy: 0.6639
# Epoch 18/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.66387 to 0.73950, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 311ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.8506 - val_accuracy: 0.7395
# Epoch 19/30
# 15/15 [==============================] - ETA: 0s - loss: 8.6726e-04 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.73950 to 0.74790, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 8.6726e-04 - accuracy: 1.0000 - val_loss: 1.7860 - val_accuracy: 0.7479
# Epoch 20/30
# 15/15 [==============================] - ETA: 0s - loss: 7.0191e-04 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.74790 to 0.75630, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 301ms/step - loss: 7.0191e-04 - accuracy: 1.0000 - val_loss: 1.7171 - val_accuracy: 0.7563
# Epoch 21/30
# 15/15 [==============================] - ETA: 0s - loss: 5.7097e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy improved from 0.75630 to 0.79832, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 303ms/step - loss: 5.7097e-04 - accuracy: 1.0000 - val_loss: 1.6489 - val_accuracy: 0.7983
# Epoch 22/30
# 15/15 [==============================] - ETA: 0s - loss: 6.0873e-04 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.79832 to 0.84874, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 301ms/step - loss: 6.0873e-04 - accuracy: 1.0000 - val_loss: 1.5768 - val_accuracy: 0.8487
# Epoch 23/30
# 15/15 [==============================] - ETA: 0s - loss: 5.0040e-04 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.84874 to 0.85714, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 5.0040e-04 - accuracy: 1.0000 - val_loss: 1.4892 - val_accuracy: 0.8571
# Epoch 24/30
# 15/15 [==============================] - ETA: 0s - loss: 5.6113e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy improved from 0.85714 to 0.87395, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 5.6113e-04 - accuracy: 1.0000 - val_loss: 1.3970 - val_accuracy: 0.8739
# Epoch 25/30
# 15/15 [==============================] - ETA: 0s - loss: 3.6918e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.87395 to 0.89076, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 3.6918e-04 - accuracy: 1.0000 - val_loss: 1.3025 - val_accuracy: 0.8908
# Epoch 26/30
# 15/15 [==============================] - ETA: 0s - loss: 2.5483e-04 - accuracy: 1.0000
# Epoch 00026: val_accuracy improved from 0.89076 to 0.92437, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 303ms/step - loss: 2.5483e-04 - accuracy: 1.0000 - val_loss: 1.2011 - val_accuracy: 0.9244
# Epoch 27/30
# 15/15 [==============================] - ETA: 0s - loss: 2.7181e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.92437 to 0.93277, saving model to saved_models(30epoch)ITARATIO\model_1.h5
# 15/15 [==============================] - 5s 303ms/step - loss: 2.7181e-04 - accuracy: 1.0000 - val_loss: 1.1015 - val_accuracy: 0.9328
# Epoch 28/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.93277
# 15/15 [==============================] - 4s 283ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0092 - val_accuracy: 0.9328
# Epoch 29/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.93277
# 15/15 [==============================] - 4s 276ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9206 - val_accuracy: 0.9328
# Epoch 30/30
# 15/15 [==============================] - ETA: 0s - loss: 5.5079e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.93277
# 15/15 [==============================] - 4s 279ms/step - loss: 5.5079e-04 - accuracy: 1.0000 - val_loss: 0.8070 - val_accuracy: 0.9160
# 4/4 [==============================] - 1s 127ms/step - loss: 1.1015 - accuracy: 0.9328
# Found 475 validated image filenames belonging to 10 classes.
# Found 119 validated image filenames belonging to 10 classes.
# Epoch 1/30
# 15/15 [==============================] - ETA: 0s - loss: 2.9891 - accuracy: 0.1179
# Epoch 00001: val_accuracy improved from -inf to 0.10924, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 323ms/step - loss: 2.9891 - accuracy: 0.1179 - val_loss: 2.3425 - val_accuracy: 0.1092
# Epoch 2/30
# 15/15 [==============================] - ETA: 0s - loss: 2.2125 - accuracy: 0.2253
# Epoch 00002: val_accuracy improved from 0.10924 to 0.14286, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 300ms/step - loss: 2.2125 - accuracy: 0.2253 - val_loss: 2.2712 - val_accuracy: 0.1429
# Epoch 3/30
# 15/15 [==============================] - ETA: 0s - loss: 1.8235 - accuracy: 0.4168
# Epoch 00003: val_accuracy improved from 0.14286 to 0.26891, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 1.8235 - accuracy: 0.4168 - val_loss: 2.2492 - val_accuracy: 0.2689
# Epoch 4/30
# 15/15 [==============================] - ETA: 0s - loss: 1.1874 - accuracy: 0.6547
# Epoch 00004: val_accuracy did not improve from 0.26891
# 15/15 [==============================] - 4s 288ms/step - loss: 1.1874 - accuracy: 0.6547 - val_loss: 2.2361 - val_accuracy: 0.1933
# Epoch 5/30
# 15/15 [==============================] - ETA: 0s - loss: 0.7877 - accuracy: 0.7516
# Epoch 00005: val_accuracy improved from 0.26891 to 0.31933, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 310ms/step - loss: 0.7877 - accuracy: 0.7516 - val_loss: 2.2273 - val_accuracy: 0.3193
# Epoch 6/30
# 15/15 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8568
# Epoch 00006: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 5s 298ms/step - loss: 0.4360 - accuracy: 0.8568 - val_loss: 2.1962 - val_accuracy: 0.3193
# Epoch 7/30
# 15/15 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.9179
# Epoch 00007: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 4s 285ms/step - loss: 0.2896 - accuracy: 0.9179 - val_loss: 2.1860 - val_accuracy: 0.1849
# Epoch 8/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9642
# Epoch 00008: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 4s 285ms/step - loss: 0.1591 - accuracy: 0.9642 - val_loss: 2.1441 - val_accuracy: 0.2521
# Epoch 9/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9705
# Epoch 00009: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 4s 281ms/step - loss: 0.1069 - accuracy: 0.9705 - val_loss: 2.0984 - val_accuracy: 0.3193
# Epoch 10/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1007 - accuracy: 0.9726
# Epoch 00010: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 4s 282ms/step - loss: 0.1007 - accuracy: 0.9726 - val_loss: 2.1021 - val_accuracy: 0.3109
# Epoch 11/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0744 - accuracy: 0.9747
# Epoch 00011: val_accuracy improved from 0.31933 to 0.42857, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 322ms/step - loss: 0.0744 - accuracy: 0.9747 - val_loss: 2.0909 - val_accuracy: 0.4286
# Epoch 12/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9832
# Epoch 00012: val_accuracy improved from 0.42857 to 0.44538, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 0.0715 - accuracy: 0.9832 - val_loss: 2.0800 - val_accuracy: 0.4454
# Epoch 13/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9937
# Epoch 00013: val_accuracy improved from 0.44538 to 0.50420, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 322ms/step - loss: 0.0282 - accuracy: 0.9937 - val_loss: 2.0333 - val_accuracy: 0.5042
# Epoch 14/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9979
# Epoch 00014: val_accuracy improved from 0.50420 to 0.51261, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 303ms/step - loss: 0.0261 - accuracy: 0.9979 - val_loss: 1.9931 - val_accuracy: 0.5126
# Epoch 15/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9979
# Epoch 00015: val_accuracy improved from 0.51261 to 0.56303, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 310ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 1.9494 - val_accuracy: 0.5630
# Epoch 16/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 00016: val_accuracy did not improve from 0.56303
# 15/15 [==============================] - 4s 286ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 1.9074 - val_accuracy: 0.5294
# Epoch 17/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00017: val_accuracy improved from 0.56303 to 0.57983, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.8483 - val_accuracy: 0.5798
# Epoch 18/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9979
# Epoch 00018: val_accuracy improved from 0.57983 to 0.66387, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 1.7321 - val_accuracy: 0.6639
# Epoch 19/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9979
# Epoch 00019: val_accuracy did not improve from 0.66387
# 15/15 [==============================] - 4s 287ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 1.7029 - val_accuracy: 0.6218
# Epoch 20/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00020: val_accuracy did not improve from 0.66387
# 15/15 [==============================] - 4s 284ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.6414 - val_accuracy: 0.6639
# Epoch 21/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9979
# Epoch 00021: val_accuracy improved from 0.66387 to 0.73950, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 0.0123 - accuracy: 0.9979 - val_loss: 1.4851 - val_accuracy: 0.7395
# Epoch 22/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 00022: val_accuracy did not improve from 0.73950
# 15/15 [==============================] - 4s 284ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.4848 - val_accuracy: 0.6723
# Epoch 23/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.73950 to 0.79832, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3983 - val_accuracy: 0.7983
# Epoch 24/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00024: val_accuracy improved from 0.79832 to 0.83193, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.3118 - val_accuracy: 0.8319
# Epoch 25/30
# 15/15 [==============================] - ETA: 0s - loss: 9.9504e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.83193 to 0.86555, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 320ms/step - loss: 9.9504e-04 - accuracy: 1.0000 - val_loss: 1.1871 - val_accuracy: 0.8655
# Epoch 26/30
# 15/15 [==============================] - ETA: 0s - loss: 6.1583e-04 - accuracy: 1.0000
# Epoch 00026: val_accuracy improved from 0.86555 to 0.87395, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 324ms/step - loss: 6.1583e-04 - accuracy: 1.0000 - val_loss: 1.0807 - val_accuracy: 0.8739
# Epoch 27/30
# 15/15 [==============================] - ETA: 0s - loss: 4.2077e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.87395 to 0.93277, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 329ms/step - loss: 4.2077e-04 - accuracy: 1.0000 - val_loss: 0.9660 - val_accuracy: 0.9328
# Epoch 28/30
# 15/15 [==============================] - ETA: 0s - loss: 5.9957e-04 - accuracy: 1.0000
# Epoch 00028: val_accuracy improved from 0.93277 to 0.95798, saving model to saved_models(30epoch)ITARATIO\model_2.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 5.9957e-04 - accuracy: 1.0000 - val_loss: 0.8688 - val_accuracy: 0.9580
# Epoch 29/30
# 15/15 [==============================] - ETA: 0s - loss: 3.2767e-04 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.95798
# 15/15 [==============================] - 4s 284ms/step - loss: 3.2767e-04 - accuracy: 1.0000 - val_loss: 0.7517 - val_accuracy: 0.9580
# Epoch 30/30
# 15/15 [==============================] - ETA: 0s - loss: 6.5057e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.95798
# 15/15 [==============================] - 4s 283ms/step - loss: 6.5057e-04 - accuracy: 1.0000 - val_loss: 0.6109 - val_accuracy: 0.9580
# 4/4 [==============================] - 1s 117ms/step - loss: 0.8688 - accuracy: 0.9580
# Found 475 validated image filenames belonging to 10 classes.
# Found 119 validated image filenames belonging to 10 classes.
# Epoch 1/30
# 15/15 [==============================] - ETA: 0s - loss: 3.4254 - accuracy: 0.0968
# Epoch 00001: val_accuracy improved from -inf to 0.10084, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 318ms/step - loss: 3.4254 - accuracy: 0.0968 - val_loss: 2.3485 - val_accuracy: 0.1008
# Epoch 2/30
# 15/15 [==============================] - ETA: 0s - loss: 2.2330 - accuracy: 0.1811
# Epoch 00002: val_accuracy improved from 0.10084 to 0.12605, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 2.2330 - accuracy: 0.1811 - val_loss: 2.2929 - val_accuracy: 0.1261
# Epoch 3/30
# 15/15 [==============================] - ETA: 0s - loss: 1.9229 - accuracy: 0.3832
# Epoch 00003: val_accuracy improved from 0.12605 to 0.15966, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 1.9229 - accuracy: 0.3832 - val_loss: 2.2835 - val_accuracy: 0.1597
# Epoch 4/30
# 15/15 [==============================] - ETA: 0s - loss: 1.2995 - accuracy: 0.6147
# Epoch 00004: val_accuracy improved from 0.15966 to 0.20168, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 1.2995 - accuracy: 0.6147 - val_loss: 2.2676 - val_accuracy: 0.2017
# Epoch 5/30
# 15/15 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.7853
# Epoch 00005: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 284ms/step - loss: 0.6900 - accuracy: 0.7853 - val_loss: 2.2581 - val_accuracy: 0.1681
# Epoch 6/30
# 15/15 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9158
# Epoch 00006: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 284ms/step - loss: 0.2665 - accuracy: 0.9158 - val_loss: 2.2592 - val_accuracy: 0.1176
# Epoch 7/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9726
# Epoch 00007: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 286ms/step - loss: 0.1134 - accuracy: 0.9726 - val_loss: 2.2379 - val_accuracy: 0.1429
# Epoch 8/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9832
# Epoch 00008: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 281ms/step - loss: 0.0947 - accuracy: 0.9832 - val_loss: 2.2356 - val_accuracy: 0.2017
# Epoch 9/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0586 - accuracy: 0.9853
# Epoch 00009: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 285ms/step - loss: 0.0586 - accuracy: 0.9853 - val_loss: 2.2235 - val_accuracy: 0.1513
# Epoch 10/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9916
# Epoch 00010: val_accuracy did not improve from 0.20168
# 15/15 [==============================] - 4s 283ms/step - loss: 0.0403 - accuracy: 0.9916 - val_loss: 2.2108 - val_accuracy: 0.1933
# Epoch 11/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9937
# Epoch 00011: val_accuracy improved from 0.20168 to 0.22689, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0289 - accuracy: 0.9937 - val_loss: 2.1843 - val_accuracy: 0.2269
# Epoch 12/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9958
# Epoch 00012: val_accuracy improved from 0.22689 to 0.27731, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 0.0215 - accuracy: 0.9958 - val_loss: 2.1691 - val_accuracy: 0.2773
# Epoch 13/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 1.0000
# Epoch 00013: val_accuracy improved from 0.27731 to 0.34454, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 2.1488 - val_accuracy: 0.3445
# Epoch 14/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9979
# Epoch 00014: val_accuracy improved from 0.34454 to 0.36134, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0187 - accuracy: 0.9979 - val_loss: 2.1554 - val_accuracy: 0.3613
# Epoch 15/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9979
# Epoch 00015: val_accuracy improved from 0.36134 to 0.46218, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0120 - accuracy: 0.9979 - val_loss: 2.1074 - val_accuracy: 0.4622
# Epoch 16/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 00016: val_accuracy improved from 0.46218 to 0.47899, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 2.0806 - val_accuracy: 0.4790
# Epoch 17/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00017: val_accuracy improved from 0.47899 to 0.57143, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0395 - val_accuracy: 0.5714
# Epoch 18/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.57143 to 0.59664, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.9897 - val_accuracy: 0.5966
# Epoch 19/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.59664 to 0.63866, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.9400 - val_accuracy: 0.6387
# Epoch 20/30
# 15/15 [==============================] - ETA: 0s - loss: 9.2780e-04 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.63866 to 0.71429, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 309ms/step - loss: 9.2780e-04 - accuracy: 1.0000 - val_loss: 1.8926 - val_accuracy: 0.7143
# Epoch 21/30
# 15/15 [==============================] - ETA: 0s - loss: 7.8413e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy improved from 0.71429 to 0.77311, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 7.8413e-04 - accuracy: 1.0000 - val_loss: 1.8105 - val_accuracy: 0.7731
# Epoch 22/30
# 15/15 [==============================] - ETA: 0s - loss: 5.5990e-04 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.77311 to 0.78151, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 312ms/step - loss: 5.5990e-04 - accuracy: 1.0000 - val_loss: 1.7414 - val_accuracy: 0.7815
# Epoch 23/30
# 15/15 [==============================] - ETA: 0s - loss: 4.6773e-04 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.78151 to 0.82353, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 4.6773e-04 - accuracy: 1.0000 - val_loss: 1.6714 - val_accuracy: 0.8235
# Epoch 24/30
# 15/15 [==============================] - ETA: 0s - loss: 3.1562e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy improved from 0.82353 to 0.84874, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 3.1562e-04 - accuracy: 1.0000 - val_loss: 1.5910 - val_accuracy: 0.8487
# Epoch 25/30
# 15/15 [==============================] - ETA: 0s - loss: 5.7160e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.84874 to 0.87395, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 5.7160e-04 - accuracy: 1.0000 - val_loss: 1.5144 - val_accuracy: 0.8739
# Epoch 26/30
# 15/15 [==============================] - ETA: 0s - loss: 7.5221e-04 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.87395
# 15/15 [==============================] - 5s 319ms/step - loss: 7.5221e-04 - accuracy: 1.0000 - val_loss: 1.4107 - val_accuracy: 0.8655
# Epoch 27/30
# 15/15 [==============================] - ETA: 0s - loss: 3.7198e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.87395 to 0.89076, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 323ms/step - loss: 3.7198e-04 - accuracy: 1.0000 - val_loss: 1.3014 - val_accuracy: 0.8908
# Epoch 28/30
# 15/15 [==============================] - ETA: 0s - loss: 5.5500e-04 - accuracy: 1.0000
# Epoch 00028: val_accuracy improved from 0.89076 to 0.90756, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 5.5500e-04 - accuracy: 1.0000 - val_loss: 1.1996 - val_accuracy: 0.9076
# Epoch 29/30
# 15/15 [==============================] - ETA: 0s - loss: 3.8782e-04 - accuracy: 1.0000
# Epoch 00029: val_accuracy improved from 0.90756 to 0.94958, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 314ms/step - loss: 3.8782e-04 - accuracy: 1.0000 - val_loss: 1.0913 - val_accuracy: 0.9496
# Epoch 30/30
# 15/15 [==============================] - ETA: 0s - loss: 2.1098e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy improved from 0.94958 to 0.95798, saving model to saved_models(30epoch)ITARATIO\model_3.h5
# 15/15 [==============================] - 5s 325ms/step - loss: 2.1098e-04 - accuracy: 1.0000 - val_loss: 0.9775 - val_accuracy: 0.9580
# 4/4 [==============================] - 1s 121ms/step - loss: 0.9775 - accuracy: 0.9580
# Found 475 validated image filenames belonging to 10 classes.
# Found 119 validated image filenames belonging to 10 classes.
# Epoch 1/30
# 15/15 [==============================] - ETA: 0s - loss: 3.1160 - accuracy: 0.1432
# Epoch 00001: val_accuracy improved from -inf to 0.09244, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 6s 339ms/step - loss: 3.1160 - accuracy: 0.1432 - val_loss: 2.3673 - val_accuracy: 0.0924
# Epoch 2/30
# 15/15 [==============================] - ETA: 0s - loss: 2.1168 - accuracy: 0.2611
# Epoch 00002: val_accuracy improved from 0.09244 to 0.12605, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 2.1168 - accuracy: 0.2611 - val_loss: 2.2753 - val_accuracy: 0.1261
# Epoch 3/30
# 15/15 [==============================] - ETA: 0s - loss: 1.6247 - accuracy: 0.4779
# Epoch 00003: val_accuracy improved from 0.12605 to 0.14286, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 1.6247 - accuracy: 0.4779 - val_loss: 2.2590 - val_accuracy: 0.1429
# Epoch 4/30
# 15/15 [==============================] - ETA: 0s - loss: 0.9743 - accuracy: 0.7305
# Epoch 00004: val_accuracy did not improve from 0.14286
# 15/15 [==============================] - 4s 282ms/step - loss: 0.9743 - accuracy: 0.7305 - val_loss: 2.2548 - val_accuracy: 0.1261
# Epoch 5/30
# 15/15 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.8653
# Epoch 00005: val_accuracy did not improve from 0.14286
# 15/15 [==============================] - 4s 297ms/step - loss: 0.4888 - accuracy: 0.8653 - val_loss: 2.2421 - val_accuracy: 0.1261
# Epoch 6/30
# 15/15 [==============================] - ETA: 0s - loss: 0.2864 - accuracy: 0.9242
# Epoch 00006: val_accuracy did not improve from 0.14286
# 15/15 [==============================] - 4s 283ms/step - loss: 0.2864 - accuracy: 0.9242 - val_loss: 2.2234 - val_accuracy: 0.1345
# Epoch 7/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9726
# Epoch 00007: val_accuracy did not improve from 0.14286
# 15/15 [==============================] - 4s 292ms/step - loss: 0.1316 - accuracy: 0.9726 - val_loss: 2.2109 - val_accuracy: 0.1429
# Epoch 8/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0637 - accuracy: 0.9874
# Epoch 00008: val_accuracy improved from 0.14286 to 0.18487, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 322ms/step - loss: 0.0637 - accuracy: 0.9874 - val_loss: 2.1774 - val_accuracy: 0.1849
# Epoch 9/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9832
# Epoch 00009: val_accuracy did not improve from 0.18487
# 15/15 [==============================] - 5s 303ms/step - loss: 0.0788 - accuracy: 0.9832 - val_loss: 2.1639 - val_accuracy: 0.1597
# Epoch 10/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9937
# Epoch 00010: val_accuracy improved from 0.18487 to 0.31933, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 310ms/step - loss: 0.0416 - accuracy: 0.9937 - val_loss: 2.1347 - val_accuracy: 0.3193
# Epoch 11/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9979
# Epoch 00011: val_accuracy did not improve from 0.31933
# 15/15 [==============================] - 4s 291ms/step - loss: 0.0173 - accuracy: 0.9979 - val_loss: 2.1128 - val_accuracy: 0.3109
# Epoch 12/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9937
# Epoch 00012: val_accuracy improved from 0.31933 to 0.42017, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 2.0676 - val_accuracy: 0.4202
# Epoch 13/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9958
# Epoch 00013: val_accuracy improved from 0.42017 to 0.42857, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0245 - accuracy: 0.9958 - val_loss: 2.0536 - val_accuracy: 0.4286
# Epoch 14/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9937
# Epoch 00014: val_accuracy improved from 0.42857 to 0.46218, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 4s 298ms/step - loss: 0.0169 - accuracy: 0.9937 - val_loss: 2.0093 - val_accuracy: 0.4622
# Epoch 15/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9937
# Epoch 00015: val_accuracy did not improve from 0.46218
# 15/15 [==============================] - 4s 280ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 1.9870 - val_accuracy: 0.4538
# Epoch 16/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9958
# Epoch 00016: val_accuracy improved from 0.46218 to 0.48739, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 1.9090 - val_accuracy: 0.4874
# Epoch 17/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00017: val_accuracy improved from 0.48739 to 0.49580, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 301ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.8670 - val_accuracy: 0.4958
# Epoch 18/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.49580 to 0.52941, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 323ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.8239 - val_accuracy: 0.5294
# Epoch 19/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.52941 to 0.59664, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 311ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.7403 - val_accuracy: 0.5966
# Epoch 20/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.59664 to 0.64706, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.6673 - val_accuracy: 0.6471
# Epoch 21/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00021: val_accuracy improved from 0.64706 to 0.68908, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.5783 - val_accuracy: 0.6891
# Epoch 22/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.68908 to 0.70588, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4990 - val_accuracy: 0.7059
# Epoch 23/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.70588 to 0.75630, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 314ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4230 - val_accuracy: 0.7563
# Epoch 24/30
# 15/15 [==============================] - ETA: 0s - loss: 6.1036e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy improved from 0.75630 to 0.86555, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 308ms/step - loss: 6.1036e-04 - accuracy: 1.0000 - val_loss: 1.2961 - val_accuracy: 0.8655
# Epoch 25/30
# 15/15 [==============================] - ETA: 0s - loss: 9.2531e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.86555 to 0.89076, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 324ms/step - loss: 9.2531e-04 - accuracy: 1.0000 - val_loss: 1.2422 - val_accuracy: 0.8908
# Epoch 26/30
# 15/15 [==============================] - ETA: 0s - loss: 6.4379e-04 - accuracy: 1.0000
# Epoch 00026: val_accuracy improved from 0.89076 to 0.92437, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 310ms/step - loss: 6.4379e-04 - accuracy: 1.0000 - val_loss: 1.0966 - val_accuracy: 0.9244
# Epoch 27/30
# 15/15 [==============================] - ETA: 0s - loss: 5.0120e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.92437 to 0.94958, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 306ms/step - loss: 5.0120e-04 - accuracy: 1.0000 - val_loss: 1.0015 - val_accuracy: 0.9496
# Epoch 28/30
# 15/15 [==============================] - ETA: 0s - loss: 4.5180e-04 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.94958
# 15/15 [==============================] - 4s 293ms/step - loss: 4.5180e-04 - accuracy: 1.0000 - val_loss: 0.9106 - val_accuracy: 0.9496
# Epoch 29/30
# 15/15 [==============================] - ETA: 0s - loss: 3.9715e-04 - accuracy: 1.0000
# Epoch 00029: val_accuracy improved from 0.94958 to 0.96639, saving model to saved_models(30epoch)ITARATIO\model_4.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 3.9715e-04 - accuracy: 1.0000 - val_loss: 0.8063 - val_accuracy: 0.9664
# Epoch 30/30
# 15/15 [==============================] - ETA: 0s - loss: 3.1221e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.96639
# 15/15 [==============================] - 4s 279ms/step - loss: 3.1221e-04 - accuracy: 1.0000 - val_loss: 0.7091 - val_accuracy: 0.9664
# 4/4 [==============================] - 1s 118ms/step - loss: 0.8063 - accuracy: 0.9664
# Found 476 validated image filenames belonging to 10 classes.
# Found 118 validated image filenames belonging to 10 classes.
# Epoch 1/30
# 15/15 [==============================] - ETA: 0s - loss: 4.6609 - accuracy: 0.1050
# Epoch 00001: val_accuracy improved from -inf to 0.11017, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 316ms/step - loss: 4.6609 - accuracy: 0.1050 - val_loss: 2.3798 - val_accuracy: 0.1102
# Epoch 2/30
# 15/15 [==============================] - ETA: 0s - loss: 2.1794 - accuracy: 0.2248
# Epoch 00002: val_accuracy improved from 0.11017 to 0.17797, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 302ms/step - loss: 2.1794 - accuracy: 0.2248 - val_loss: 2.2763 - val_accuracy: 0.1780
# Epoch 3/30
# 15/15 [==============================] - ETA: 0s - loss: 1.5761 - accuracy: 0.4895
# Epoch 00003: val_accuracy improved from 0.17797 to 0.22881, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 1.5761 - accuracy: 0.4895 - val_loss: 2.2325 - val_accuracy: 0.2288
# Epoch 4/30
# 15/15 [==============================] - ETA: 0s - loss: 1.0390 - accuracy: 0.6618
# Epoch 00004: val_accuracy improved from 0.22881 to 0.23729, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 1.0390 - accuracy: 0.6618 - val_loss: 2.1925 - val_accuracy: 0.2373
# Epoch 5/30
# 15/15 [==============================] - ETA: 0s - loss: 0.6270 - accuracy: 0.8214
# Epoch 00005: val_accuracy did not improve from 0.23729
# 15/15 [==============================] - 4s 280ms/step - loss: 0.6270 - accuracy: 0.8214 - val_loss: 2.1974 - val_accuracy: 0.1610
# Epoch 6/30
# 15/15 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.9097
# Epoch 00006: val_accuracy improved from 0.23729 to 0.31356, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 299ms/step - loss: 0.3617 - accuracy: 0.9097 - val_loss: 2.1647 - val_accuracy: 0.3136
# Epoch 7/30
# 15/15 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9433
# Epoch 00007: val_accuracy did not improve from 0.31356
# 15/15 [==============================] - 4s 279ms/step - loss: 0.2050 - accuracy: 0.9433 - val_loss: 2.1450 - val_accuracy: 0.2542
# Epoch 8/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9412
# Epoch 00008: val_accuracy did not improve from 0.31356
# 15/15 [==============================] - 4s 279ms/step - loss: 0.1881 - accuracy: 0.9412 - val_loss: 2.1321 - val_accuracy: 0.2797
# Epoch 9/30
# 15/15 [==============================] - ETA: 0s - loss: 0.1598 - accuracy: 0.9601
# Epoch 00009: val_accuracy improved from 0.31356 to 0.36441, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.1598 - accuracy: 0.9601 - val_loss: 2.0643 - val_accuracy: 0.3644
# Epoch 10/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9874
# Epoch 00010: val_accuracy did not improve from 0.36441
# 15/15 [==============================] - 4s 282ms/step - loss: 0.0756 - accuracy: 0.9874 - val_loss: 2.0317 - val_accuracy: 0.3136
# Epoch 11/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0666 - accuracy: 0.9874
# Epoch 00011: val_accuracy improved from 0.36441 to 0.38136, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0666 - accuracy: 0.9874 - val_loss: 1.9879 - val_accuracy: 0.3814
# Epoch 12/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9916
# Epoch 00012: val_accuracy improved from 0.38136 to 0.45763, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 330ms/step - loss: 0.0471 - accuracy: 0.9916 - val_loss: 1.9264 - val_accuracy: 0.4576
# Epoch 13/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9874
# Epoch 00013: val_accuracy did not improve from 0.45763
# 15/15 [==============================] - 4s 292ms/step - loss: 0.0448 - accuracy: 0.9874 - val_loss: 1.9692 - val_accuracy: 0.3136
# Epoch 14/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9895
# Epoch 00014: val_accuracy improved from 0.45763 to 0.54237, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0589 - accuracy: 0.9895 - val_loss: 1.8230 - val_accuracy: 0.5424
# Epoch 15/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9979
# Epoch 00015: val_accuracy improved from 0.54237 to 0.56780, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 322ms/step - loss: 0.0213 - accuracy: 0.9979 - val_loss: 1.7946 - val_accuracy: 0.5678
# Epoch 16/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9895
# Epoch 00016: val_accuracy did not improve from 0.56780
# 15/15 [==============================] - 4s 295ms/step - loss: 0.0403 - accuracy: 0.9895 - val_loss: 1.7443 - val_accuracy: 0.4661
# Epoch 17/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9958
# Epoch 00017: val_accuracy improved from 0.56780 to 0.58475, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 320ms/step - loss: 0.0380 - accuracy: 0.9958 - val_loss: 1.7304 - val_accuracy: 0.5847
# Epoch 18/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9937
# Epoch 00018: val_accuracy improved from 0.58475 to 0.63559, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 1.6593 - val_accuracy: 0.6356
# Epoch 19/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9979
# Epoch 00019: val_accuracy did not improve from 0.63559
# 15/15 [==============================] - 4s 285ms/step - loss: 0.0170 - accuracy: 0.9979 - val_loss: 1.5167 - val_accuracy: 0.6271
# Epoch 20/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.63559 to 0.81356, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.3825 - val_accuracy: 0.8136
# Epoch 21/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.81356
# 15/15 [==============================] - 4s 293ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.3546 - val_accuracy: 0.7881
# Epoch 22/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.81356 to 0.83898, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2917 - val_accuracy: 0.8390
# Epoch 23/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.83898 to 0.90678, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1662 - val_accuracy: 0.9068
# Epoch 24/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.90678
# 15/15 [==============================] - 4s 283ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1470 - val_accuracy: 0.8983
# Epoch 25/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.90678 to 0.94915, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 304ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0307 - val_accuracy: 0.9492
# Epoch 26/30
# 15/15 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00026: val_accuracy improved from 0.94915 to 0.96610, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8680 - val_accuracy: 0.9661
# Epoch 27/30
# 15/15 [==============================] - ETA: 0s - loss: 9.7597e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.96610 to 0.97458, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 305ms/step - loss: 9.7597e-04 - accuracy: 1.0000 - val_loss: 0.7962 - val_accuracy: 0.9746
# Epoch 28/30
# 15/15 [==============================] - ETA: 0s - loss: 9.8132e-04 - accuracy: 1.0000
# Epoch 00028: val_accuracy improved from 0.97458 to 0.98305, saving model to saved_models(30epoch)ITARATIO\model_5.h5
# 15/15 [==============================] - 5s 307ms/step - loss: 9.8132e-04 - accuracy: 1.0000 - val_loss: 0.6971 - val_accuracy: 0.9831
# Epoch 29/30
# 15/15 [==============================] - ETA: 0s - loss: 5.2732e-04 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.98305
# 15/15 [==============================] - 4s 285ms/step - loss: 5.2732e-04 - accuracy: 1.0000 - val_loss: 0.6051 - val_accuracy: 0.9831
# Epoch 30/30
# 15/15 [==============================] - ETA: 0s - loss: 9.0855e-04 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.98305
# 15/15 [==============================] - 4s 284ms/step - loss: 9.0855e-04 - accuracy: 1.0000 - val_loss: 0.5099 - val_accuracy: 0.9831
# 4/4 [==============================] - 1s 118ms/step - loss: 0.6971 - accuracy: 0.9831

# %%
VALIDATION_ACCURACY
# Out:
# [0.9327731132507324,
#  0.9579831957817078,
#  0.9579831957817078,
#  0.9663865566253662,
#  0.9830508232116699]

# %%
VALIDATION_LOSS
# Out:
# [1.1014575958251953,
#  0.8687536120414734,
#  0.9774883985519409,
#  0.8063441514968872,
#  0.6971389651298523]
