# %%
import os
import numpy as np
import pandas as pd
import tensorflow
from keras.models import Sequential # To initialise the nn as a sequence of layers
from keras.layers import Convolution2D # To make the convolution layer for 2D images
from keras.layers import MaxPooling2D # 
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import CSVLogger
from tensorflow.keras.optimizers import RMSprop
from keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow import data
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from tensorflow import repeat as rp

csv=CSVLogger("2_adam.log")
#filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
#checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')


# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Convolution2D(32,(2,2),input_shape = (224,224,1), activation = 'relu',strides=2,name='convo1'))
classifier.add(Convolution2D(64,(3,3), activation = 'relu',name='convo2'))
# Step 1 - Pooling
classifier.add(MaxPooling2D(pool_size = (2,2)))

# Step 2 - Convolution
classifier.add(Convolution2D(64,(3,3),activation = 'relu',name='convo3'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2,2)))
# Step 3 - Convolution
classifier.add(Convolution2D(64,(3,3),activation = 'relu',name='convo4'))
# Step 3 - Pooling
classifier.add(MaxPooling2D(pool_size = (2,2)))
#Step 4 - Flattening

classifier.add(Flatten())

classifier.add(BatchNormalization())
classifier.add(Dropout((0.5)))
classifier.add(Dense(1024, activation = 'relu'))

'''classifier.add(BatchNormalization())
classifier.add(Dropout((0.5)))
classifier.add(Dense(512, activation = 'relu'))
'''

classifier.add(BatchNormalization())
classifier.add(Dropout((0.4)))
classifier.add(Dense(20, activation = 'softmax'))

# %%
import matplotlib.pyplot as plt
adam = Adam(epsilon = 0.01)
classifier.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

curr_path = os.getcwd()
basefolder = os.path.dirname(curr_path)
train_folder = os.path.join(basefolder, "Dataset\\Train")
test_folder = os.path.join(basefolder, "Dataset\\dev")
train_set=tensorflow.data
train_set = train_datagen.flow_from_directory(train_folder,target_size=(224, 224),batch_size=32,class_mode='categorical',color_mode='grayscale')


test_set = test_datagen.flow_from_directory(test_folder,target_size=(224, 224),batch_size=32,class_mode='categorical',color_mode='grayscale')
classifier.metrics_names
# Out:
# Found 5170 images belonging to 40 classes.
# Found 400 images belonging to 40 classes.
# []

# %%
#nb_conda_kernels

# %%
history = classifier.fit(train_set,steps_per_epoch=train_set.n/32,epochs=100,validation_data=test_set,validation_steps=test_set.n/32,callbacks=[csv],verbose=1)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 41s 496ms/step - loss: 3.5180 - accuracy: 0.1269 - val_loss: 2.9872 - val_accuracy: 0.0300
# Epoch 2/100
# 80/80 [==============================] - 39s 481ms/step - loss: 2.2367 - accuracy: 0.3571 - val_loss: 2.9411 - val_accuracy: 0.0950
# Epoch 3/100
# 80/80 [==============================] - 39s 486ms/step - loss: 1.5422 - accuracy: 0.5246 - val_loss: 2.8101 - val_accuracy: 0.1300
# Epoch 4/100
# 80/80 [==============================] - 39s 488ms/step - loss: 1.0585 - accuracy: 0.6627 - val_loss: 2.6981 - val_accuracy: 0.2250
# Epoch 5/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.7526 - accuracy: 0.7501 - val_loss: 2.4303 - val_accuracy: 0.2450
# Epoch 6/100
# 80/80 [==============================] - 40s 498ms/step - loss: 0.5547 - accuracy: 0.8116 - val_loss: 2.3157 - val_accuracy: 0.3050
# Epoch 7/100
# 80/80 [==============================] - 41s 507ms/step - loss: 0.3630 - accuracy: 0.8882 - val_loss: 2.2515 - val_accuracy: 0.2850
# Epoch 8/100
# 80/80 [==============================] - 40s 500ms/step - loss: 0.3301 - accuracy: 0.8983 - val_loss: 2.7613 - val_accuracy: 0.3050
# Epoch 9/100
# 80/80 [==============================] - 41s 502ms/step - loss: 0.2327 - accuracy: 0.9250 - val_loss: 3.1913 - val_accuracy: 0.2900
# Epoch 10/100
# 80/80 [==============================] - 40s 501ms/step - loss: 0.2045 - accuracy: 0.9350 - val_loss: 2.5815 - val_accuracy: 0.4150
# Epoch 11/100
# 80/80 [==============================] - 42s 522ms/step - loss: 0.1662 - accuracy: 0.9513 - val_loss: 4.6074 - val_accuracy: 0.3950
# Epoch 12/100
# 80/80 [==============================] - 41s 506ms/step - loss: 0.1503 - accuracy: 0.9563 - val_loss: 4.2245 - val_accuracy: 0.2900
# Epoch 13/100
# 80/80 [==============================] - 41s 503ms/step - loss: 0.1527 - accuracy: 0.9509 - val_loss: 2.9784 - val_accuracy: 0.3750
# Epoch 14/100
# 80/80 [==============================] - 40s 501ms/step - loss: 0.1279 - accuracy: 0.9605 - val_loss: 4.0041 - val_accuracy: 0.3500
# Epoch 15/100
# 80/80 [==============================] - 40s 500ms/step - loss: 0.0938 - accuracy: 0.9752 - val_loss: 3.6593 - val_accuracy: 0.4000
# Epoch 16/100
# 80/80 [==============================] - 41s 507ms/step - loss: 0.0959 - accuracy: 0.9694 - val_loss: 3.8395 - val_accuracy: 0.3800
# Epoch 17/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0777 - accuracy: 0.9787 - val_loss: 4.9356 - val_accuracy: 0.3500
# Epoch 18/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0870 - accuracy: 0.9702 - val_loss: 3.8048 - val_accuracy: 0.3300
# Epoch 19/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0955 - accuracy: 0.9725 - val_loss: 3.6030 - val_accuracy: 0.3800
# Epoch 20/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 3.7985 - val_accuracy: 0.3950
# Epoch 21/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0705 - accuracy: 0.9787 - val_loss: 3.4983 - val_accuracy: 0.3550
# Epoch 22/100
# 80/80 [==============================] - 40s 497ms/step - loss: 0.0568 - accuracy: 0.9826 - val_loss: 3.3342 - val_accuracy: 0.3950
# Epoch 23/100
# 80/80 [==============================] - 40s 498ms/step - loss: 0.0699 - accuracy: 0.9783 - val_loss: 3.3253 - val_accuracy: 0.4400
# Epoch 24/100
# 80/80 [==============================] - 40s 499ms/step - loss: 0.0472 - accuracy: 0.9880 - val_loss: 3.5697 - val_accuracy: 0.3750
# Epoch 25/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0414 - accuracy: 0.9865 - val_loss: 3.9885 - val_accuracy: 0.4100
# Epoch 26/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0387 - accuracy: 0.9903 - val_loss: 3.7456 - val_accuracy: 0.3750
# Epoch 27/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0355 - accuracy: 0.9926 - val_loss: 4.1366 - val_accuracy: 0.3750
# Epoch 28/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0362 - accuracy: 0.9915 - val_loss: 2.9650 - val_accuracy: 0.4300
# Epoch 29/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0323 - accuracy: 0.9896 - val_loss: 3.9912 - val_accuracy: 0.3800
# Epoch 30/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0429 - accuracy: 0.9865 - val_loss: 5.2948 - val_accuracy: 0.2800
# Epoch 31/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0385 - accuracy: 0.9888 - val_loss: 3.0331 - val_accuracy: 0.4600
# Epoch 32/100
# 80/80 [==============================] - 40s 497ms/step - loss: 0.0350 - accuracy: 0.9896 - val_loss: 3.6426 - val_accuracy: 0.3900
# Epoch 33/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0345 - accuracy: 0.9899 - val_loss: 3.6092 - val_accuracy: 0.4350
# Epoch 34/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0289 - accuracy: 0.9934 - val_loss: 3.6154 - val_accuracy: 0.4150
# Epoch 35/100
# 80/80 [==============================] - 40s 493ms/step - loss: 0.0289 - accuracy: 0.9930 - val_loss: 3.2643 - val_accuracy: 0.4800
# Epoch 36/100
# 80/80 [==============================] - 40s 493ms/step - loss: 0.0347 - accuracy: 0.9919 - val_loss: 3.2181 - val_accuracy: 0.4750
# Epoch 37/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0360 - accuracy: 0.9892 - val_loss: 4.4884 - val_accuracy: 0.3700
# Epoch 38/100
# 80/80 [==============================] - 41s 506ms/step - loss: 0.0201 - accuracy: 0.9957 - val_loss: 3.4687 - val_accuracy: 0.4250
# Epoch 39/100
# 80/80 [==============================] - 41s 504ms/step - loss: 0.0252 - accuracy: 0.9930 - val_loss: 4.5565 - val_accuracy: 0.3800
# Epoch 40/100
# 80/80 [==============================] - 42s 515ms/step - loss: 0.0287 - accuracy: 0.9923 - val_loss: 6.8456 - val_accuracy: 0.3000
# Epoch 41/100
# 80/80 [==============================] - 40s 497ms/step - loss: 0.0360 - accuracy: 0.9907 - val_loss: 6.4319 - val_accuracy: 0.3400
# Epoch 42/100
# 80/80 [==============================] - 40s 489ms/step - loss: 0.0312 - accuracy: 0.9903 - val_loss: 4.5333 - val_accuracy: 0.3500
# Epoch 43/100
# 80/80 [==============================] - 39s 480ms/step - loss: 0.0339 - accuracy: 0.9903 - val_loss: 4.4626 - val_accuracy: 0.4100
# Epoch 44/100
# 80/80 [==============================] - 39s 485ms/step - loss: 0.0390 - accuracy: 0.9861 - val_loss: 3.9464 - val_accuracy: 0.3600
# Epoch 45/100
# 80/80 [==============================] - 39s 483ms/step - loss: 0.0365 - accuracy: 0.9896 - val_loss: 4.6092 - val_accuracy: 0.3600
# Epoch 46/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0374 - accuracy: 0.9884 - val_loss: 6.2059 - val_accuracy: 0.3400
# Epoch 47/100
# 80/80 [==============================] - 40s 492ms/step - loss: 0.0278 - accuracy: 0.9930 - val_loss: 3.3134 - val_accuracy: 0.4100
# Epoch 48/100
# 80/80 [==============================] - 40s 493ms/step - loss: 0.0330 - accuracy: 0.9903 - val_loss: 3.3593 - val_accuracy: 0.4700
# Epoch 49/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0317 - accuracy: 0.9903 - val_loss: 4.1956 - val_accuracy: 0.4200
# Epoch 50/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0251 - accuracy: 0.9911 - val_loss: 3.5162 - val_accuracy: 0.4300
# Epoch 51/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0238 - accuracy: 0.9946 - val_loss: 5.2550 - val_accuracy: 0.3100
# Epoch 52/100
# 80/80 [==============================] - 41s 509ms/step - loss: 0.0330 - accuracy: 0.9907 - val_loss: 4.1927 - val_accuracy: 0.3850
# Epoch 53/100
# 80/80 [==============================] - 42s 514ms/step - loss: 0.0302 - accuracy: 0.9899 - val_loss: 5.5593 - val_accuracy: 0.3350
# Epoch 54/100
# 80/80 [==============================] - 41s 508ms/step - loss: 0.0374 - accuracy: 0.9872 - val_loss: 6.3838 - val_accuracy: 0.3250
# Epoch 55/100
# 80/80 [==============================] - 40s 499ms/step - loss: 0.0501 - accuracy: 0.9857 - val_loss: 3.9108 - val_accuracy: 0.3800
# Epoch 56/100
# 80/80 [==============================] - 41s 504ms/step - loss: 0.0531 - accuracy: 0.9807 - val_loss: 7.5633 - val_accuracy: 0.2700
# Epoch 57/100
# 80/80 [==============================] - 40s 499ms/step - loss: 0.0278 - accuracy: 0.9926 - val_loss: 3.4591 - val_accuracy: 0.4950
# Epoch 58/100
# 80/80 [==============================] - 41s 509ms/step - loss: 0.0283 - accuracy: 0.9899 - val_loss: 3.9348 - val_accuracy: 0.4750
# Epoch 59/100
# 80/80 [==============================] - 41s 504ms/step - loss: 0.0332 - accuracy: 0.9896 - val_loss: 6.7310 - val_accuracy: 0.2650
# Epoch 60/100
# 80/80 [==============================] - 41s 511ms/step - loss: 0.0301 - accuracy: 0.9923 - val_loss: 4.4305 - val_accuracy: 0.4350
# Epoch 61/100
# 80/80 [==============================] - 41s 503ms/step - loss: 0.0218 - accuracy: 0.9930 - val_loss: 5.4254 - val_accuracy: 0.3900
# Epoch 62/100
# 80/80 [==============================] - 41s 504ms/step - loss: 0.0258 - accuracy: 0.9926 - val_loss: 2.9033 - val_accuracy: 0.4400
# Epoch 63/100
# 80/80 [==============================] - 40s 498ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 3.8699 - val_accuracy: 0.4100
# Epoch 64/100
# 80/80 [==============================] - 40s 493ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 5.5694 - val_accuracy: 0.3800
# Epoch 65/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0131 - accuracy: 0.9973 - val_loss: 3.9498 - val_accuracy: 0.4450
# Epoch 66/100
# 80/80 [==============================] - 41s 502ms/step - loss: 0.0180 - accuracy: 0.9954 - val_loss: 4.3983 - val_accuracy: 0.4050
# Epoch 67/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 4.3210 - val_accuracy: 0.4550
# Epoch 68/100
# 80/80 [==============================] - 40s 494ms/step - loss: 0.0155 - accuracy: 0.9938 - val_loss: 4.4003 - val_accuracy: 0.3900
# Epoch 69/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0125 - accuracy: 0.9969 - val_loss: 4.8680 - val_accuracy: 0.4250
# Epoch 70/100
# 80/80 [==============================] - 40s 493ms/step - loss: 0.0098 - accuracy: 0.9988 - val_loss: 2.9938 - val_accuracy: 0.4900
# Epoch 71/100
# 80/80 [==============================] - 41s 506ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 4.2660 - val_accuracy: 0.4400
# Epoch 72/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0177 - accuracy: 0.9934 - val_loss: 4.4210 - val_accuracy: 0.4000
# Epoch 73/100
# 80/80 [==============================] - 40s 499ms/step - loss: 0.0239 - accuracy: 0.9919 - val_loss: 3.5732 - val_accuracy: 0.4150
# Epoch 74/100
# 80/80 [==============================] - 40s 500ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 3.1738 - val_accuracy: 0.4850
# Epoch 75/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0177 - accuracy: 0.9957 - val_loss: 4.5148 - val_accuracy: 0.3450
# Epoch 76/100
# 80/80 [==============================] - 41s 506ms/step - loss: 0.0270 - accuracy: 0.9899 - val_loss: 5.3212 - val_accuracy: 0.3400
# Epoch 77/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0239 - accuracy: 0.9930 - val_loss: 6.7206 - val_accuracy: 0.3300
# Epoch 78/100
# 80/80 [==============================] - 41s 503ms/step - loss: 0.0438 - accuracy: 0.9876 - val_loss: 5.0989 - val_accuracy: 0.3950
# Epoch 79/100
# 80/80 [==============================] - 40s 495ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 4.3890 - val_accuracy: 0.4100
# Epoch 80/100
# 80/80 [==============================] - 41s 508ms/step - loss: 0.0276 - accuracy: 0.9911 - val_loss: 4.4555 - val_accuracy: 0.4300
# Epoch 81/100
# 80/80 [==============================] - 41s 503ms/step - loss: 0.0307 - accuracy: 0.9911 - val_loss: 4.8931 - val_accuracy: 0.4650
# Epoch 82/100
# 80/80 [==============================] - 40s 499ms/step - loss: 0.0311 - accuracy: 0.9880 - val_loss: 5.2285 - val_accuracy: 0.3200
# Epoch 83/100
# 80/80 [==============================] - 40s 496ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 4.1091 - val_accuracy: 0.4350
# Epoch 84/100
# 80/80 [==============================] - 41s 504ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 4.0484 - val_accuracy: 0.4250
# Epoch 85/100
# 80/80 [==============================] - 40s 491ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 3.9161 - val_accuracy: 0.4650
# Epoch 86/100
# 80/80 [==============================] - 38s 471ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 3.0206 - val_accuracy: 0.5200
# Epoch 87/100
# 80/80 [==============================] - 38s 470ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 5.3615 - val_accuracy: 0.4050
# Epoch 88/100
# 80/80 [==============================] - 38s 471ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 3.5638 - val_accuracy: 0.4550
# Epoch 89/100
# 80/80 [==============================] - 38s 473ms/step - loss: 0.0116 - accuracy: 0.9985 - val_loss: 3.4971 - val_accuracy: 0.4750
# Epoch 90/100
# 80/80 [==============================] - 38s 472ms/step - loss: 0.0143 - accuracy: 0.9961 - val_loss: 4.1160 - val_accuracy: 0.4350
# Epoch 91/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 3.2226 - val_accuracy: 0.5150
# Epoch 92/100
# 80/80 [==============================] - 38s 476ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 3.5195 - val_accuracy: 0.4600
# Epoch 93/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0156 - accuracy: 0.9946 - val_loss: 4.8341 - val_accuracy: 0.4450
# Epoch 94/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0217 - accuracy: 0.9919 - val_loss: 4.4753 - val_accuracy: 0.4200
# Epoch 95/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0230 - accuracy: 0.9930 - val_loss: 4.4819 - val_accuracy: 0.4250
# Epoch 96/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0134 - accuracy: 0.9961 - val_loss: 3.1534 - val_accuracy: 0.5400
# Epoch 97/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 4.5028 - val_accuracy: 0.4200
# Epoch 98/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 3.7358 - val_accuracy: 0.4650
# Epoch 99/100
# 80/80 [==============================] - 38s 475ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 4.1777 - val_accuracy: 0.4150
# Epoch 100/100
# 80/80 [==============================] - 38s 474ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 4.4071 - val_accuracy: 0.3900

# %%
classifier.save('2_adam_new2.h5')

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy']) #validation
plt.plot(history.history['val_accuracy']) #train
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22116/107946140.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(history.history['accuracy']) #validation
#       3 plt.plot(history.history['val_accuracy']) #train
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined
